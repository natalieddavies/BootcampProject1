# %%
# DEPENDENCIES
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from datetime import datetime

# DATA FILES
path_crime_data = "Data/crime_data.csv"

# READ CRIME DATA
raw_crime_data = pd.read_csv(path_crime_data)
raw_crime_data
# Out:
#             Website Region  WAPOL_Hierarchy_order_Lvl1  \
# 0        Armadale District                         1.1
# 1        Armadale District                         1.1
# 2        Armadale District                         1.1
# 3        Armadale District                         1.1
# 4        Armadale District                         1.1
# ...                    ...                         ...
# 143095  Wheatbelt District                        20.3
# 143096  Wheatbelt District                        20.3
# 143097  Wheatbelt District                        20.3
# 143098  Wheatbelt District                        20.3
# 143099  Wheatbelt District                        20.3
#
#           WAPOL_Hierarchy_Lvl1  WAPOL_Hierarchy_order_Lvl2  \
# 0                       Murder                           1
# 1                       Murder                           1
# 2                       Murder                           1
# 3                       Murder                           1
# 4                       Murder                           1
# ...                        ...                         ...
# 143095  Breach of Police Order                          20
# 143096  Breach of Police Order                          20
# 143097  Breach of Police Order                          20
# 143098  Breach of Police Order                          20
# 143099  Breach of Police Order                          20
#
#                       WAPOL_Hierarchy_Lvl2    Period     Year  \
# 0                                 Homicide  1-Jan-07  2006-07
# 1                                 Homicide  1-Feb-07  2006-07
# 2                                 Homicide  1-Mar-07  2006-07
# 3                                 Homicide  1-Apr-07  2006-07
# 4                                 Homicide  1-May-07  2006-07
# ...                                    ...       ...      ...
# 143095  Breach of Violence Restraint Order  1-Nov-19  2019-20
# 143096  Breach of Violence Restraint Order  1-Dec-19  2019-20
# 143097  Breach of Violence Restraint Order  1-Jan-20  2019-20
# 143098  Breach of Violence Restraint Order  1-Feb-20  2019-20
# 143099  Breach of Violence Restraint Order  1-Mar-20  2019-20
#
#                                                       Key  MonthYear  \
# 0                    Armadale DistrictMurderHomicide12007      12007
# 1                    Armadale DistrictMurderHomicide22007      22007
# 2                    Armadale DistrictMurderHomicide32007      32007
# 3                    Armadale DistrictMurderHomicide42007      42007
# 4                    Armadale DistrictMurderHomicide52007      52007
# ...                                                   ...        ...
# 143095  Wheatbelt DistrictBreach of Police OrderBreach...     112019
# 143096  Wheatbelt DistrictBreach of Police OrderBreach...     122019
# 143097  Wheatbelt DistrictBreach of Police OrderBreach...      12020
# 143098  Wheatbelt DistrictBreach of Police OrderBreach...      22020
# 143099  Wheatbelt DistrictBreach of Police OrderBreach...      32020
#
#         COUNT_of_Offnc_ID
# 0                     NaN
# 1                     NaN
# 2                     1.0
# 3                     NaN
# 4                     NaN
# ...                   ...
# 143095                5.0
# 143096                7.0
# 143097                5.0
# 143098                1.0
# 143099                4.0
#
# [143100 rows x 10 columns]

# %%
# DROP IRRELEVANT COLUMNS
del raw_crime_data['WAPOL_Hierarchy_order_Lvl1']

# %%
del raw_crime_data['WAPOL_Hierarchy_order_Lvl2']

# %%
del raw_crime_data['Year']

# %%
del raw_crime_data['Key']

# %%
del raw_crime_data['MonthYear']

# %%
raw_crime_data
# Out:
#             Website Region    WAPOL_Hierarchy_Lvl1  \
# 0        Armadale District                  Murder
# 1        Armadale District                  Murder
# 2        Armadale District                  Murder
# 3        Armadale District                  Murder
# 4        Armadale District                  Murder
# ...                    ...                     ...
# 143095  Wheatbelt District  Breach of Police Order
# 143096  Wheatbelt District  Breach of Police Order
# 143097  Wheatbelt District  Breach of Police Order
# 143098  Wheatbelt District  Breach of Police Order
# 143099  Wheatbelt District  Breach of Police Order
#
#                       WAPOL_Hierarchy_Lvl2    Period  COUNT_of_Offnc_ID
# 0                                 Homicide  1-Jan-07                NaN
# 1                                 Homicide  1-Feb-07                NaN
# 2                                 Homicide  1-Mar-07                1.0
# 3                                 Homicide  1-Apr-07                NaN
# 4                                 Homicide  1-May-07                NaN
# ...                                    ...       ...                ...
# 143095  Breach of Violence Restraint Order  1-Nov-19                5.0
# 143096  Breach of Violence Restraint Order  1-Dec-19                7.0
# 143097  Breach of Violence Restraint Order  1-Jan-20                5.0
# 143098  Breach of Violence Restraint Order  1-Feb-20                1.0
# 143099  Breach of Violence Restraint Order  1-Mar-20                4.0
#
# [143100 rows x 5 columns]

# %%
raw_crime_data = raw_crime_data.rename(columns={"Website Region":"District", 
                               "WAPOL_Hierarchy_Lvl1":"Offence Group", 
                               "WAPOL_Hierarchy_Lvl2":"Offence", 
                               "Period":"Offence Date", 
                               "COUNT_of_Offnc_ID":"Total Number of Offences"})
raw_crime_data
# Out:
#                   District           Offence Group  \
# 0        Armadale District                  Murder
# 1        Armadale District                  Murder
# 2        Armadale District                  Murder
# 3        Armadale District                  Murder
# 4        Armadale District                  Murder
# ...                    ...                     ...
# 143095  Wheatbelt District  Breach of Police Order
# 143096  Wheatbelt District  Breach of Police Order
# 143097  Wheatbelt District  Breach of Police Order
# 143098  Wheatbelt District  Breach of Police Order
# 143099  Wheatbelt District  Breach of Police Order
#
#                                    Offence Offence Date  \
# 0                                 Homicide     1-Jan-07
# 1                                 Homicide     1-Feb-07
# 2                                 Homicide     1-Mar-07
# 3                                 Homicide     1-Apr-07
# 4                                 Homicide     1-May-07
# ...                                    ...          ...
# 143095  Breach of Violence Restraint Order     1-Nov-19
# 143096  Breach of Violence Restraint Order     1-Dec-19
# 143097  Breach of Violence Restraint Order     1-Jan-20
# 143098  Breach of Violence Restraint Order     1-Feb-20
# 143099  Breach of Violence Restraint Order     1-Mar-20
#
#         Total Number of Offences
# 0                            NaN
# 1                            NaN
# 2                            1.0
# 3                            NaN
# 4                            NaN
# ...                          ...
# 143095                       5.0
# 143096                       7.0
# 143097                       5.0
# 143098                       1.0
# 143099                       4.0
#
# [143100 rows x 5 columns]

# %%
list(raw_crime_data.columns)
# Out:
# ['District',
#  'Offence Group',
#  'Offence',
#  'Offence Date',
#  'Total Number of Offences']

# %%
# new data frame with split value columns 
new = raw_crime_data["Offence Date"].str.split("-", n = 2, expand = True) 
# making separate first name column from new data frame 
raw_crime_data["Month"]= new[1]
# making separate last name column from new data frame 
raw_crime_data["Year"]= new[2]
raw_crime_data
# Out:
#                   District           Offence Group  \
# 0        Armadale District                  Murder
# 1        Armadale District                  Murder
# 2        Armadale District                  Murder
# 3        Armadale District                  Murder
# 4        Armadale District                  Murder
# ...                    ...                     ...
# 143095  Wheatbelt District  Breach of Police Order
# 143096  Wheatbelt District  Breach of Police Order
# 143097  Wheatbelt District  Breach of Police Order
# 143098  Wheatbelt District  Breach of Police Order
# 143099  Wheatbelt District  Breach of Police Order
#
#                                    Offence Offence Date  \
# 0                                 Homicide     1-Jan-07
# 1                                 Homicide     1-Feb-07
# 2                                 Homicide     1-Mar-07
# 3                                 Homicide     1-Apr-07
# 4                                 Homicide     1-May-07
# ...                                    ...          ...
# 143095  Breach of Violence Restraint Order     1-Nov-19
# 143096  Breach of Violence Restraint Order     1-Dec-19
# 143097  Breach of Violence Restraint Order     1-Jan-20
# 143098  Breach of Violence Restraint Order     1-Feb-20
# 143099  Breach of Violence Restraint Order     1-Mar-20
#
#         Total Number of Offences Month Year
# 0                            NaN   Jan   07
# 1                            NaN   Feb   07
# 2                            1.0   Mar   07
# 3                            NaN   Apr   07
# 4                            NaN   May   07
# ...                          ...   ...  ...
# 143095                       5.0   Nov   19
# 143096                       7.0   Dec   19
# 143097                       5.0   Jan   20
# 143098                       1.0   Feb   20
# 143099                       4.0   Mar   20
#
# [143100 rows x 7 columns]

# %%
del raw_crime_data['Offence Date']

# %%
#convert year column from string into integer
raw_crime_data['Year'] = raw_crime_data['Year'].astype(int)

# %%
#remove data prior to 2010
raw_crime_data.loc[raw_crime_data["Year"]>=10]
# Out:
#                   District           Offence Group  \
# 36       Armadale District                  Murder
# 37       Armadale District                  Murder
# 38       Armadale District                  Murder
# 39       Armadale District                  Murder
# 40       Armadale District                  Murder
# ...                    ...                     ...
# 143095  Wheatbelt District  Breach of Police Order
# 143096  Wheatbelt District  Breach of Police Order
# 143097  Wheatbelt District  Breach of Police Order
# 143098  Wheatbelt District  Breach of Police Order
# 143099  Wheatbelt District  Breach of Police Order
#
#                                    Offence  Total Number of Offences Month  \
# 36                                Homicide                       2.0   Jan
# 37                                Homicide                       2.0   Feb
# 38                                Homicide                       NaN   Mar
# 39                                Homicide                       NaN   Apr
# 40                                Homicide                       NaN   May
# ...                                    ...                       ...   ...
# 143095  Breach of Violence Restraint Order                       5.0   Nov
# 143096  Breach of Violence Restraint Order                       7.0   Dec
# 143097  Breach of Violence Restraint Order                       5.0   Jan
# 143098  Breach of Violence Restraint Order                       1.0   Feb
# 143099  Breach of Violence Restraint Order                       4.0   Mar
#
#         Year
# 36        10
# 37        10
# 38        10
# 39        10
# 40        10
# ...      ...
# 143095    19
# 143096    19
# 143097    20
# 143098    20
# 143099    20
#
# [110700 rows x 6 columns]

# %%
#groupby offenc
raw_crime_data.to_csv('crimedataclean.csv',sep=',')

# %%
grouped = raw_crime_data.groupby(['District', 'Offence Group']) 
  
grouped.first()
# Out:
#                                                                                          Offence  \
# District           Offence Group
# Armadale District  Assault Police Officer                                   Assault (Non-Family)
#                    Attempted / Conspiracy to Murder                                     Homicide
#                    Breach of Family Violence Restraint Order  Breach of Violence Restraint Order
#                    Breach of Police Order                     Breach of Violence Restraint Order
#                    Breach of Violence Restraint Order         Breach of Violence Restraint Order
# ...                                                                                          ...
# Wheatbelt District Stealing From Retail Premises (Shoplift)                             Stealing
#                    Stealing as a Servant                                                Stealing
#                    Stealing of Motor Vehicle                           Stealing of Motor Vehicle
#                    Threatening Behaviour (Family)                 Threatening Behaviour (Family)
#                    Threatening Behaviour (Non-Family)         Threatening Behaviour (Non-Family)
#
#                                                               Total Number of Offences  \
# District           Offence Group
# Armadale District  Assault Police Officer                                          3.0
#                    Attempted / Conspiracy to Murder                                1.0
#                    Breach of Family Violence Restraint Order                      53.0
#                    Breach of Police Order                                          2.0
#                    Breach of Violence Restraint Order                              4.0
# ...                                                                                ...
# Wheatbelt District Stealing From Retail Premises (Shoplift)                       11.0
#                    Stealing as a Servant                                           1.0
#                    Stealing of Motor Vehicle                                       8.0
#                    Threatening Behaviour (Family)                                  2.0
#                    Threatening Behaviour (Non-Family)                              7.0
#
#                                                              Month  Year
# District           Offence Group
# Armadale District  Assault Police Officer                      Jan     7
#                    Attempted / Conspiracy to Murder            Jan     7
#                    Breach of Family Violence Restraint Order   Jan     7
#                    Breach of Police Order                      Jan     7
#                    Breach of Violence Restraint Order          Jan     7
# ...                                                            ...   ...
# Wheatbelt District Stealing From Retail Premises (Shoplift)    Jan     7
#                    Stealing as a Servant                       Jan     7
#                    Stealing of Motor Vehicle                   Jan     7
#                    Threatening Behaviour (Family)              Jan     7
#                    Threatening Behaviour (Non-Family)          Jan     7
#
# [864 rows x 4 columns]

# %%
grouped_district
# Out:
#                                 0  \
# 0               Armadale District
# 1             Cannington District
# 2              Fremantle District
# 3   Goldfields-Esperance District
# 4         Great Southern District
# 5              Joondalup District
# 6              Kimberley District
# 7               Mandurah District
# 8             Metropolitan Region
# 9      Mid West-Gascoyne District
# 10               Midland District
# 11            Mirrabooka District
# 12                 Perth District
# 13               Pilbara District
# 14             Regional WA Region
# 15            South West District
# 16              Western Australia
# 17             Wheatbelt District
#
#                                                     1
# 0   0                       Murder
# 1              ...
# 1   7950                     Murder
# 7951          ...
# 2   15900                    Murder
# 15901         ...
# 3   23850                    Murder
# 23851         ...
# 4   31800                    Murder
# 31801         ...
# 5   39750                    Murder
# 39751         ...
# 6   47700                    Murder
# 47701         ...
# 7   55650                    Murder
# 55651         ...
# 8   63600                    Murder
# 63601         ...
# 9   71550                    Murder
# 71551         ...
# 10  79500                    Murder
# 79501         ...
# 11  87450                    Murder
# 87451         ...
# 12  95400                     Murder
# 95401        ...
# 13  103350                    Murder
# 103351       ...
# 14  111300                    Murder
# 111301       ...
# 15  119250                    Murder
# 119251       ...
# 16  127200                    Murder
# 127201       ...
# 17  135150                    Murder
# 135151       ...
