# %%
# DEPENDENCIES
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import scipy.stats as st
from pandasdmx import Request
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandasdmx/remote.py:11: RuntimeWarning: optional dependency requests_cache is not installed; cache options to Session() have no effect
#   'to Session() have no effect', RuntimeWarning)

# %%
Agency_Code = 'ABS'
#Dataset_Id = 'ABS_C16_T13_SA'
ABS = Request(Agency_Code)
data_response = ABS.data(resource_id='ABS_C16_T13_LGA', params={'startPeriod': '2016'})
#This will result into a stacked DataFrame
#income_df = data_response.write(data_response.data.series, parse_time=False)
#A flat DataFrame
#data_response.write().unstack().reset_index()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-c69635d2de35> in <module>
#       2 #Dataset_Id = 'ABS_C16_T13_SA'
#       3 ABS = Request(Agency_Code)
# ----> 4 data_response = ABS.data(resource_id='ABS_C16_T13_LGA', params={'startPeriod': '2016'})
#       5 #This will result into a stacked DataFrame
#       6 #income_df = data_response.write(data_response.data.series, parse_time=False)
#
# /opt/anaconda3/lib/python3.7/site-packages/pandasdmx/api.py in get(self, resource_type, resource_id, tofile, use_cache, dry_run, dsd, **kwargs)
#     422         # Only if   SDMXML content is given, use any provided or auto-queried DSD.
#     423         if 'json' in content_type:
# --> 424             msg = reader.read_message(response_content)
#     425         else:
#     426             msg = reader.read_message(response_content,
#
# /opt/anaconda3/lib/python3.7/site-packages/pandasdmx/reader/sdmxjson.py in read_message(self, source)
#     100         # Read DataSets
#     101         for ds in tree['dataSets']:
# --> 102             msg.data.append(self.read_dataset(ds, ds_key))
#     103
#     104         return msg
#
# /opt/anaconda3/lib/python3.7/site-packages/pandasdmx/reader/sdmxjson.py in read_dataset(self, root, ds_key)
#     110         # Process series
#     111         for key_values, elem in root.get('series', {}).items():
# --> 112             series_key = self._make_key('series', key_values, base=ds_key)
#     113             series_key.attrib = self._make_attrs('series',
#     114                                                  root.get('attributes', []))
#
# /opt/anaconda3/lib/python3.7/site-packages/pandasdmx/reader/sdmxjson.py in _make_key(self, level, value, base)
#     145             'series': SeriesKey,
#     146             'observation': Key,
# --> 147             }[level]()
#     148
#     149         if base:
#
# /opt/anaconda3/lib/python3.7/site-packages/pandasdmx/model.py in __init__(self, arg, **kwargs)
#    1276
#    1277         # Sort the values according to *order*
# -> 1278         self.values.update({kv.id: kv for _, kv in sorted(values)})
#    1279
#    1280     def __len__(self):
#
# KeyboardInterrupt:

# %%
income_df

# %%
url="http://stat.data.abs.gov.au/sdmx-json/data/ABS_C16_T13_LGA/TOT+10+11+12+13+14+15+Z+01+02+03+04+05+06+07+08+09.A15+A20+A25+A30+A35+A40+A45+A50+A55+A60+A65+A70+A75+A80+A85+A90+A95+A99+TT.1+3+2.5.LGA2016+LGA....?detail=Full&dimensionAtObservation=AllDimensions&startPeriod=2016"

# %%
# DATA FILES
path_income_data = "Data/income_data.csv"

# READ CRIME DATA
raw_income_data = pd.read_csv(path_income_data)
raw_income_data

# %%
raw_income_data.columns
# Out:
# Index(['INCP_2016', 'Total Personal Income - weekly', 'AGE', 'Age', 'SEX_ABS',
#        'Sex', 'STATE', 'State', 'REGIONTYPE', 'Geography Level', 'LGA_2016',
#        'Region', 'TIME', 'Census year', 'Value', 'Flag Codes', 'Flags'],
#       dtype='object')

# %%
raw_income_data=raw_income_data.drop(['Flag Codes','Flags','TIME','REGIONTYPE','Geography Level','SEX_ABS'],1)

# %%
raw_income_data
# Out:
#        INCP_2016 Total Personal Income - weekly  AGE      Age      Sex  STATE  \
# 0            TOT                          Total  A15  15 - 19    Males      1
# 1            TOT                          Total  A15  15 - 19  Females      1
# 2            TOT                          Total  A15  15 - 19  Persons      1
# 3            TOT                          Total  A15  15 - 19    Males      1
# 4            TOT                          Total  A15  15 - 19  Females      1
# ...          ...                            ...  ...      ...      ...    ...
# 164019         5   $300-$399 ($15,600-$20,799)   A40  40 - 44    Males      1
# 164020         5   $300-$399 ($15,600-$20,799)   A40  40 - 44  Females      1
# 164021         5   $300-$399 ($15,600-$20,799)   A40  40 - 44  Persons      1
# 164022         5   $300-$399 ($15,600-$20,799)   A40  40 - 44    Males      1
# 164023         5   $300-$399 ($15,600-$20,799)   A40  40 - 44  Females      1
#
#                   State  LGA_2016                 Region  Census year  \
# 0       New South Wales     10050             Albury (C)         2016
# 1       New South Wales     10050             Albury (C)         2016
# 2       New South Wales     10050             Albury (C)         2016
# 3       New South Wales     10130  Armidale Regional (A)         2016
# 4       New South Wales     10130  Armidale Regional (A)         2016
# ...                 ...       ...                    ...          ...
# 164019  New South Wales     14600            Lachlan (A)         2016
# 164020  New South Wales     14600            Lachlan (A)         2016
# 164021  New South Wales     14600            Lachlan (A)         2016
# 164022  New South Wales     14650     Lake Macquarie (C)         2016
# 164023  New South Wales     14650     Lake Macquarie (C)         2016
#
#                                                     Value
# 0                                                    1611
# 1                                                    1635
# 2                                                    3248
# 3                                                    1254
# 4                                                    1302
# ...                                                   ...
# 164019                                                 10
# 164020                                                 12
# 164021                                                 25
# 164022                                                200
# 164023  Internal Server Error - Thread was being aborted.
#
# [164024 rows x 11 columns]

# %%
income_data=raw_income_data[raw_income_data["State"] =="Western Australia"]
income_data
# Out:
#        INCP_2016 Total Personal Income - weekly  AGE      Age      Sex  STATE  \
# 1101         TOT                          Total  A15  15 - 19    Males      5
# 1102         TOT                          Total  A15  15 - 19  Females      5
# 1103         TOT                          Total  A15  15 - 19  Persons      5
# 1104         TOT                          Total  A15  15 - 19    Males      5
# 1105         TOT                          Total  A15  15 - 19  Females      5
# ...          ...                            ...  ...      ...      ...    ...
# 163657        04     $150-$299 ($7,800-$15,599)  A40  40 - 44  Females      5
# 163658        04     $150-$299 ($7,800-$15,599)  A40  40 - 44  Persons      5
# 163659        04     $150-$299 ($7,800-$15,599)  A40  40 - 44    Males      5
# 163660        04     $150-$299 ($7,800-$15,599)  A40  40 - 44  Females      5
# 163661        04     $150-$299 ($7,800-$15,599)  A40  40 - 44  Persons      5
#
#                     State  LGA_2016                                Region  \
# 1101    Western Australia     50080                            Albany (C)
# 1102    Western Australia     50080                            Albany (C)
# 1103    Western Australia     50080                            Albany (C)
# 1104    Western Australia     50210                          Armadale (C)
# 1105    Western Australia     50210                          Armadale (C)
# ...                   ...       ...                                   ...
# 163657  Western Australia     59499                 No usual address (WA)
# 163658  Western Australia     59499                 No usual address (WA)
# 163659  Western Australia     59799  Migratory - Offshore - Shipping (WA)
# 163660  Western Australia     59799  Migratory - Offshore - Shipping (WA)
# 163661  Western Australia     59799  Migratory - Offshore - Shipping (WA)
#
#         Census year Value
# 1101           2016  1252
# 1102           2016  1156
# 1103           2016  2404
# 1104           2016  2361
# 1105           2016  2331
# ...             ...   ...
# 163657         2016    41
# 163658         2016   110
# 163659         2016     4
# 163660         2016     0
# 163661         2016     4
#
# [40449 rows x 11 columns]
